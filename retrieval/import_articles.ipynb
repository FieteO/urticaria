# %%
# imports
import glob
import os
import re
import numpy as np
import pandas as pd

# %%
# configure dataframe appearance
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
# save current working dir
cwd = os.getcwd()

# move one directory up to process global input files
os.chdir('..')

# read files from folder to dataframe
directory = './input/corpus/txtfiles_from_ocr/'
file_type = 'txt'
files = glob.glob("%s*.%s" % (directory, file_type))
df_files = pd.DataFrame(files, columns=['Filepath'])

# %%
# create checksum for each file to identify duplicates
# https://stackoverflow.com/questions/16874598/how-do-i-calculate-the-md5-checksum-of-a-file-in-python#16876405
import hashlib
def get_checksum(filepath: str) -> str:
    # Open,close, read file and calculate MD5 on its contents 
    with open(filepath, 'rb') as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        return hashlib.md5(data).hexdigest()
df_files['Checksum'] = df_files['Filepath'].apply(get_checksum)
df_files
# Out:
#                                                Filepath  \
# 0     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 1     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 2     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 3     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 4     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# ...                                                 ...
# 1041  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1042  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1043  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1044  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1045  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
#
#                               Checksum
# 0     614144a0ffce9742be6d03e5d1f4327e
# 1     c70d4b5962b0baf267ad6574647815b1
# 2     94c1dcf77c98a1836066064856559340
# 3     73df94431b67b6f923b42db2113ec885
# 4     1ffa62ca53c5993d420bfdb2b230ab35
# ...                                ...
# 1041  1fc4032881cf480619bf7f24e48bb6b9
# 1042  f8179511c0b0643af87ce227ac553b98
# 1043  2c8067cf5b2aae6d59bb5175a75dde4e
# 1044  267aef8aa2b0e343c8f78002953cd2f3
# 1045  892d367fc80152a906741c5f5215bd01
#
# [1046 rows x 2 columns]

# %%
# define functions to gather basic informations from the article files
def get_text_from_file(path: str) -> str:
    file = open(path,mode='r')
    text = file.read()
    file.close()
    return text

def get_year_from_file(path: str) -> str:    
    year = re.findall("\d+", path[-22:-17])[0]
    return year

def get_markers_from_file(path: str, id: int) -> str:
    info = os.path.basename(path).split("_")
    return info[id]

def get_authors_from_file(path: str) -> str:
    info = os.path.basename(path).split("_")
    return info[3][:-9]

# %%
# read basic informations from article files into dataframe
article_collection = []
for article in df_files.Filepath:
    article_details = {
        'Marker_1' : get_markers_from_file(article, 1),
        'Marker_2' : get_markers_from_file(article, 2),
        'Authors' : get_authors_from_file(article),
        'Year' : get_year_from_file(article),
        'Fulltext' : get_text_from_file(article),
    }
    article_collection.append(article_details)
df = pd.DataFrame(article_collection).join(df_files)

# reset working dir after input files have been processed
os.chdir(cwd)

df
# Out:
#                Marker_1       Marker_2      Authors  Year  \
# 0     Allergic Diseases     Angioedema  Arik yilmaz  2017
# 1     Allergic Diseases     Angioedema        Bruno  2001
# 2     Allergic Diseases     Angioedema       Cousin  2016
# 3     Allergic Diseases     Angioedema      Faisant  2016
# 4     Allergic Diseases     Angioedema      Kahveci  2020
# ...                 ...            ...          ...   ...
# 1041                TPO  Thyroglobulin         Levy  2003
# 1042                TPO  Thyroglobulin       Mozena  2010
# 1043                TPO  Thyroglobulin      Sanchez  2020
# 1044                TPO  Thyroglobulin     Silvares  2017
# 1045                TPO  Thyroglobulin          Wan  2012
#
#                                                Fulltext  \
# 0     The persistence of chronic spontaneous urticar...
# 1     the Science of the\nTotal Environment\n\nAn In...
# 2     Received Date : 11-Jan-2016\nRevised Date : 27...
# 3      \n\nExperimental Imm\n\nology\n\nORIGINAL ART...
# 4     Allergol Immunopathol (Madr). 2020;48(4):368-3...
# ...                                                 ...
# 1041  ORIGINAL ARTICLE\n\n517\n\nChronic urticaria: ...
# 1042  ORIGINAL ARTICLE\n\n \n\nLack of a Role for Cr...
# 1043  Journal Pre-proof\n\nIdentification of antigen...
# 1044  Report\n\nInternational Journal of\n\nDermatol...
# 1045  Endocr Res Downloaded from informahealthcare.c...
#
#                                                Filepath  \
# 0     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 1     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 2     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 3     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 4     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# ...                                                 ...
# 1041  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1042  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1043  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1044  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1045  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
#
#                               Checksum
# 0     614144a0ffce9742be6d03e5d1f4327e
# 1     c70d4b5962b0baf267ad6574647815b1
# 2     94c1dcf77c98a1836066064856559340
# 3     73df94431b67b6f923b42db2113ec885
# 4     1ffa62ca53c5993d420bfdb2b230ab35
# ...                                ...
# 1041  1fc4032881cf480619bf7f24e48bb6b9
# 1042  f8179511c0b0643af87ce227ac553b98
# 1043  2c8067cf5b2aae6d59bb5175a75dde4e
# 1044  267aef8aa2b0e343c8f78002953cd2f3
# 1045  892d367fc80152a906741c5f5215bd01
#
# [1046 rows x 7 columns]

# %%
# collect all markers for every unique document and append it to the dataframe as given markers
checksums = df['Checksum'].unique()
unique_markers_collection = []
for checksum in checksums:
    markers = df.loc[df['Checksum'] == checksum, ['Marker_1', 'Marker_2']]
    unique_markers = pd.unique(markers.values.ravel())  
    df.loc[df['Checksum'] == checksum, 'Given_Markers'] = ', '.join(map(str, unique_markers))
df
# Out:
#                Marker_1       Marker_2      Authors  Year  \
# 0     Allergic Diseases     Angioedema  Arik yilmaz  2017
# 1     Allergic Diseases     Angioedema        Bruno  2001
# 2     Allergic Diseases     Angioedema       Cousin  2016
# 3     Allergic Diseases     Angioedema      Faisant  2016
# 4     Allergic Diseases     Angioedema      Kahveci  2020
# ...                 ...            ...          ...   ...
# 1041                TPO  Thyroglobulin         Levy  2003
# 1042                TPO  Thyroglobulin       Mozena  2010
# 1043                TPO  Thyroglobulin      Sanchez  2020
# 1044                TPO  Thyroglobulin     Silvares  2017
# 1045                TPO  Thyroglobulin          Wan  2012
#
#                                                Fulltext  \
# 0     The persistence of chronic spontaneous urticar...
# 1     the Science of the\nTotal Environment\n\nAn In...
# 2     Received Date : 11-Jan-2016\nRevised Date : 27...
# 3      \n\nExperimental Imm\n\nology\n\nORIGINAL ART...
# 4     Allergol Immunopathol (Madr). 2020;48(4):368-3...
# ...                                                 ...
# 1041  ORIGINAL ARTICLE\n\n517\n\nChronic urticaria: ...
# 1042  ORIGINAL ARTICLE\n\n \n\nLack of a Role for Cr...
# 1043  Journal Pre-proof\n\nIdentification of antigen...
# 1044  Report\n\nInternational Journal of\n\nDermatol...
# 1045  Endocr Res Downloaded from informahealthcare.c...
#
#                                                Filepath  \
# 0     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 1     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 2     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 3     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# 4     ./input/corpus/txtfiles_from_ocr\CAPTUM_Allerg...
# ...                                                 ...
# 1041  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1042  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1043  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1044  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
# 1045  ./input/corpus/txtfiles_from_ocr\CAPTUM_TPO_Th...
#
#                               Checksum  \
# 0     614144a0ffce9742be6d03e5d1f4327e
# 1     c70d4b5962b0baf267ad6574647815b1
# 2     94c1dcf77c98a1836066064856559340
# 3     73df94431b67b6f923b42db2113ec885
# 4     1ffa62ca53c5993d420bfdb2b230ab35
# ...                                ...
# 1041  1fc4032881cf480619bf7f24e48bb6b9
# 1042  f8179511c0b0643af87ce227ac553b98
# 1043  2c8067cf5b2aae6d59bb5175a75dde4e
# 1044  267aef8aa2b0e343c8f78002953cd2f3
# 1045  892d367fc80152a906741c5f5215bd01
#
#                                           Given_Markers
# 0     Allergic Diseases, Angioedema, Duration, Severity
# 1                         Allergic Diseases, Angioedema
# 2                         Allergic Diseases, Angioedema
# 3     Allergic Diseases, Angioedema, Duration, Antih...
# 4     Allergic Diseases, Angioedema, Duration, Omali...
# ...                                                 ...
# 1041                            Thyroglobulin, ANA, TPO
# 1042           ASST, thyroglobulin, TPO, Thyroglobulin
# 1043                                 TPO, Thyroglobulin
# 1044           ASST, thyroglobulin, TPO, Thyroglobulin
# 1045                                 TPO, Thyroglobulin
#
# [1046 rows x 8 columns]

# %%
# create dataframe for further analytics w/o the duplicate articles
df_analyze = df.drop_duplicates(subset=['Checksum'], keep='first')
df_analyze.reset_index(inplace=True, drop=True)
df_analyze = df_analyze.loc[:,['Authors', 'Year', 'Given_Markers', 'Fulltext']]
df_analyze
# Out:
#                  Authors  Year  \
# 0            Arik yilmaz  2017
# 1                  Bruno  2001
# 2                 Cousin  2016
# 3                Faisant  2016
# 4                Kahveci  2020
# ..                   ...   ...
# 449              Sánchez  2019
# 450    Czarnecka-Operacz  2017
# 451  Kasumagic-Halilovic  2017
# 452              Sanchez  2020
# 453                  Wan  2012
#
#                                          Given_Markers  \
# 0    Allergic Diseases, Angioedema, Duration, Severity
# 1                        Allergic Diseases, Angioedema
# 2                        Allergic Diseases, Angioedema
# 3    Allergic Diseases, Angioedema, Duration, Antih...
# 4    Allergic Diseases, Angioedema, Duration, Omali...
# ..                                                 ...
# 449                                      TPO, Severity
# 450                                 TPO, Thyroglobulin
# 451                                 TPO, Thyroglobulin
# 452                                 TPO, Thyroglobulin
# 453                                 TPO, Thyroglobulin
#
#                                               Fulltext
# 0    The persistence of chronic spontaneous urticar...
# 1    the Science of the\nTotal Environment\n\nAn In...
# 2    Received Date : 11-Jan-2016\nRevised Date : 27...
# 3     \n\nExperimental Imm\n\nology\n\nORIGINAL ART...
# 4    Allergol Immunopathol (Madr). 2020;48(4):368-3...
# ..                                                 ...
# 449  Hindawi\n\nJournal of Immunology Research\n\nV...
# 450  Original paper\n\nThyroid function and thyroid...
# 451  Published online:05/02/2017\n\nORIGINAL PAPER\...
# 452  Journal Pre-proof\n\nIdentification of antigen...
# 453  Endocr Res Downloaded from informahealthcare.c...
#
# [454 rows x 4 columns]
